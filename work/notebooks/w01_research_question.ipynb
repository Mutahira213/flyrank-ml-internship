# %% [markdown]
# <a href="https://colab.research.google.com/github/Mutahira213/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Mutahira213/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ### Lane: CTR / Engagement Opportunity Scoring
#
# I want to investigate which pages with meaningful search visibility may have opportunities to improve click-through and engagement. This lane is useful because pages can receive substantial search impressions without generating proportionate clicks. I want to use measurable search and content-performance signals to identify pages that may deserve closer CTR or engagement review and provide a prioritization approach for SEO or content teams.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# ### Decision
#
# The decision is which pages should be prioritized for CTR or engagement review.
#
# ### Who acts
#
# An SEO or content team would use the prioritization output to decide which pages to investigate first and where to focus limited optimization effort.
#
# ### Action
#
# The team could review the highest-priority pages for possible improvements to search-result presentation, content relevance, or other measurable engagement-related factors.
#
# ### Cost of a wrong call
#
# A false priority could waste SEO or editorial time on a page with limited opportunity. Missing a genuinely promising page could delay a potentially useful improvement. Therefore, the scoring should be treated as decision support, not as an automatic recommendation or guarantee of improved CTR.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/Mutahira213/flyrank-ml-internship/main/data/raw/content_refresh_anonymized.csv"

df = pd.read_csv(url)

print("Rows:", len(df))
print("Columns:", len(df.columns))
print("Unique clients:", df["client_id"].nunique())
# Out:
# Rows: 30000
# Columns: 44
# Unique clients: 32

# %% [markdown]
# ### Quick data check
#
# The starter dataset contains 30,000 pages. The median page received 731 impressions over the last 90 days, while the median CTR was 0.07%. In addition, 22,006 pages had at least 100 impressions, giving a substantial set of pages with measurable search visibility.
#
# These numbers make CTR opportunity worth investigating because many pages receive measurable impressions but relatively few clicks. The next steps can examine whether search-performance signals can help prioritize pages for CTR or engagement review.

# %%
print("CTR / engagement related columns:")

for col in df.columns:
    if any(term in col.lower() for term in ["ctr", "click", "impression", "engagement"]):
        print(col)
# Out:
# CTR / engagement related columns:
# impressions_90d
# clicks_90d
# days_with_impressions
# impressions_last_30d
# clicks_last_30d
# impressions_prev_30d
# clicks_prev_30d
# ctr
# engagement_rate
# impression_tier

# %%
# Inspect likely CTR, click, and impression columns

for col in df.columns:
    if any(term in col.lower() for term in ["ctr", "click", "impression"]):
        print(f"\n{col}")
        print(df[col].describe())
# Out:
# impressions_90d
# count     30000.000000
# mean       5200.366300
# std       16838.019547
# min           1.000000
# 25%          81.000000
# 50%         731.000000
# 75%        3615.250000
# max      517715.000000
# Name: impressions_90d, dtype: float64
#
# clicks_90d
# count    30000.000000
# mean        16.097333
# std         75.076958
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          7.000000
# max       4178.000000
# Name: clicks_90d, dtype: float64
#
# days_with_impressions
# count    30000.000000
# mean        61.454033
# std         32.689245
# min          1.000000
# 25%         31.000000
# 50%         81.000000
# 75%         88.000000
# max         88.000000
# Name: days_with_impressions, dtype: float64
#
# impressions_last_30d
# count     30000.000000
# mean       1429.058733
# std        5643.852081
# min           0.000000
# 25%          10.000000
# 50%         139.000000
# 75%         768.000000
# max      238796.000000
# ...

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# ### What I can claim
#
# This work can identify observed patterns in CTR, impressions, clicks, and engagement-related signals. The resulting score can provide directional, decision-support information for prioritizing pages that may deserve further investigation.
#
# ### What I cannot claim
#
# This analysis cannot prove that a page's CTR will increase after an intervention, establish causal relationships, or predict Google's ranking algorithm. A high opportunity score should be treated as a prioritization signal that requires human review and further validation.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
